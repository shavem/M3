# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def graph(csv_file):
    df = pd.read_csv(csv_file)
    ax.scatter(df['x'], df['y'])

def line(equation):
    x = np.linspace(0,10,100)
    y = eval(equation)
    ax.plot(x, y, color="red", label="fitted line")
    ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,5))


graph("cities/table.csv");
line("x/3")
plt.show()
